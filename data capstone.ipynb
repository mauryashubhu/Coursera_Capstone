# %% [markdown]
# # Data Capstone project
# ###### Here we will learn about data capstone project and its working like location data provider

# %%
import pandas as pd

# %%
import numpy as nm

# %%
print('Hello Capstone Project Course!
')
# Out:
#   File "<ipython-input-3-b0869b4c7588>", line 1
#     print('Hello Capstone Project Course!
#                                          ^
# SyntaxError: EOL while scanning string literal
